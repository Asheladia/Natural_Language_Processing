# %% [markdown]
# # Correlating Returns

# %%
import os
import pandas as pd
from datetime import datetime, timedelta
from dotenv import load_dotenv
import alpaca_trade_api as tradeapi
from newsapi.newsapi_client import NewsApiClient
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %% [markdown]
# ## Load API Keys from Environment Variables

# %%
load_dotenv()
# Out:
# True

# %%
# Load .env enviroment variables
load_dotenv(dotenv_path = '../Api_keys.env')

# Set News API Key
newsapi = NewsApiClient(api_key= os.environ['news_api'])

# Set Alpaca API key and secret
alpaca_api_key = os.getenv("ALPACA_API_KEY")
alpaca_secret_key = os.getenv("ALPACA_SECRET_KEY")

api = tradeapi.REST(alpaca_api_key, alpaca_secret_key, api_version='v2')

# %% [markdown]
# ## Get AAPL Returns for Past Month

# %%
# Set the ticker
ticker = "AAPL"

# Set timeframe to '1D'
timeframe = "1D"

# Set current date and the date from one month ago using the ISO format
current_date = pd.Timestamp("2020-11-29", tz="America/New_York").isoformat()
past_date = pd.Timestamp("2020-10-31", tz="America/New_York").isoformat()

# Get 4 weeks worth of historical data for AAPL
df = api.get_barset(
    ticker,
    timeframe,
    limit=None,
    start=past_date,
    end=current_date,
    after=None,
    until=None,
).df

# Display data
df.head()
# Out:
#                              AAPL
#                              open    high       low    close     volume
# time
# 2020-11-02 00:00:00-05:00  109.11  110.68  107.3200  108.770  106260834
# 2020-11-03 00:00:00-05:00  109.66  111.47  108.7300  110.375   93660131
# 2020-11-04 00:00:00-05:00  114.14  115.59  112.3500  114.940  114505478
# 2020-11-05 00:00:00-05:00  117.99  119.62  116.8686  118.990  107993032
# 2020-11-06 00:00:00-05:00  118.32  119.20  116.1300  118.685   99225280

# %%
# Drop Outer Table Level
df = df.droplevel(axis=1, level=0)

# Use the drop function to drop extra columns
df = df.drop(columns=["open", "high", "low", "volume"])

# Since this is daily data, we can keep only the date (remove the time) component of the data
df.index = df.index.date

# Display sample data
df.head()
# Out:
#               close
# 2020-10-29  114.520
# 2020-10-30  108.900
# 2020-11-02  108.770
# 2020-11-03  110.375
# 2020-11-04  114.940

# %%
# Use the `pct_change` function to calculate daily returns of AAPL
aapl_returns = df.pct_change().dropna()

# Display sample data
aapl_returns.head()
# Out:
#                                AAPL
#                                open      high       low     close    volume
# time
# 2020-11-03 00:00:00-05:00  0.005041  0.007138  0.013138  0.014756 -0.118583
# 2020-11-04 00:00:00-05:00  0.040854  0.036961  0.033293  0.041359  0.222564
# 2020-11-05 00:00:00-05:00  0.033731  0.034865  0.040219  0.035236 -0.056875
# 2020-11-06 00:00:00-05:00  0.002797 -0.003511 -0.006320 -0.002563 -0.081188
# 2020-11-09 00:00:00-05:00  0.018425  0.023406 -0.000689 -0.019927  0.303629

# %%
# Use newsapi client to get most relevant 20 headlines per day in the past month
def get_headlines(keyword):
    all_headlines = []
    all_dates = []    
    date = datetime.strptime(current_date[:10], "%Y-%m-%d")
    end_date = datetime.strptime(past_date[:10], "%Y-%m-%d")
    print(f"Fetching news about '{keyword}'")
    print("*" * 30)
    while date > end_date:
        print(f"retrieving news from: {date}")
        articles = newsapi.get_everything(
            q=keyword,
            from_param=str(date),
            to=str(date),
            language="en",
            sort_by="relevancy",
            page=1,
        )
        headlines = []
        for i in range(0, len(articles["articles"])):
            headlines.append(articles["articles"][i]["title"])
        all_headlines.append(headlines)
        all_dates.append(date)
        date = date - timedelta(days=1)
    return all_headlines, all_dates

# %%
# Get first topic
aapl_headlines, dates = get_headlines("aapl")
aapl_headlines
# Out:
# Fetching news about 'aapl'
# ******************************
# retrieving news from: 2020-11-29 00:00:00
# retrieving news from: 2020-11-28 00:00:00
# retrieving news from: 2020-11-27 00:00:00
# retrieving news from: 2020-11-26 00:00:00
# retrieving news from: 2020-11-25 00:00:00
# retrieving news from: 2020-11-24 00:00:00
# retrieving news from: 2020-11-23 00:00:00
# retrieving news from: 2020-11-22 00:00:00
# retrieving news from: 2020-11-21 00:00:00
# retrieving news from: 2020-11-20 00:00:00
# retrieving news from: 2020-11-19 00:00:00
# retrieving news from: 2020-11-18 00:00:00
# retrieving news from: 2020-11-17 00:00:00
# retrieving news from: 2020-11-16 00:00:00
# retrieving news from: 2020-11-15 00:00:00
# retrieving news from: 2020-11-14 00:00:00
# retrieving news from: 2020-11-13 00:00:00
# retrieving news from: 2020-11-12 00:00:00
# retrieving news from: 2020-11-11 00:00:00
# retrieving news from: 2020-11-10 00:00:00
# retrieving news from: 2020-11-09 00:00:00
# retrieving news from: 2020-11-08 00:00:00
# retrieving news from: 2020-11-07 00:00:00
# retrieving news from: 2020-11-06 00:00:00
# retrieving news from: 2020-11-05 00:00:00
# retrieving news from: 2020-11-04 00:00:00
# retrieving news from: 2020-11-03 00:00:00
# retrieving news from: 2020-11-02 00:00:00
# retrieving news from: 2020-11-01 00:00:00
# [['BTS’s ‘BE’ Opens At No. 1 With One Of The Largest Debuts Of 2020',
#   'Parallels、macOS 11 Big Surに対応した「Parallels Desktop for Mac 1.6.1 App Store Edition」をリリース。',
#   'Mariah Carey Continues Christmas Legacy With Star-Studded Holiday Special',
#   'Amazonのサイバーマンデーセールで、AnkerのThunderbolt 3/USB-C Dockや急速充電器、Bluetoothスピーカーフォン/イヤホンなどが特別価格で販売中。',
#   'Why Connected Fitness Tech Popularity Will Outlast Covid-19',
#   'As The Dow Jones Industrial Average Reaches 30,000, ‘The Fed Did It’ Narrative Becomes Even More Ridiculous',
#   'Media Advisory - Hidden-Camera Footage Exposes Shocking Animal Cruelty at Ontario Pig Farm',
#   'Black Friday store traffic down 52% even as online retail sales hit record high',
#   'Buttery Smooth: The Mac ARMed',
#   'How the biggest companies are the worst investments',
#   'EXD: Breaking Away From Its Peers',
#   'Inside Scoop: A Giant Fund Sold Alibaba, Apple, and Intel Stock. Here’s What It Bought.'],
#  ['文章作成ツール「Scrivener 3 for macOS/Windows」がブラックフライデーで25%OFFセール中。',
#   'ブラックフライデーセールでScreens 4やDaisyDisk、Unclutter、SideNotes、HazeOverなどのMac用ユーティリティが特別価格で販売中。',
#   'Amazonのブラックフライデーセールで、古いMacBook Air/Pro、Mac miniで利用可能なSamsungやCrucial、Western DigitalのNVMe SSDなどが特選タイムセール中。',
#   "Barron's Picks And Pans This Week: Apple, Ford, Royal Dutch Shell, Tesla And A Hair Salon Chain",
#   'Dow Jones Futures: Stock Market Rally Flashes Mixed Signals; Watch Apple, Nio, Zoom Video, CrowdStrike',
#   'AMD, Apple Chipmakers Qorvo, Qualcomm Lead 5 Stocks Near Buy Points',
#   'Retirement: Portfolio For Income And Growth',
#   'Company Close Updates: CDW Corp. stock rises Friday, still underperforms market',
#   'Company Close Updates: Xerox Holdings Corp. stock underperforms Friday when compared to competitors',
#   'Company Close Updates: Best Buy Co. Inc. stock underperforms Friday when compared to competitors',
#   'Company Close Updates: Autodesk Inc. stock outperforms market on strong trading day',
#   'A Bumpy Road For Bitcoin As It Heads For Record Territory, As Square Lit A Fuse',
#   "Tracking Bruce Berkowitz's Fairholme Portfolio - Q3 2020 Update"],
#  [': States with stricter Thanksgiving coronavirus gathering curbs saw higher online retail sales: Adobe',
#   'Blackmagic、Apple M1チップ搭載のMacに対応したストレージベンチマークアプリ「Disk Speed Test v3.3」をリリース。',
#   'macOS 11 Big SurやApple SiliconをサポートしたMac用ネットワークモニタリングアプリ「WiFi Explorer」や「WiFi Signal」がブラックフライデーセールで最大50%OFFセール中。',
#   'ODS、Mac用ネットワーク監視アプリ「Little Snitch 5」やランチャー「LaunchBar 6」などを最大30%OFFで販売するブラックフライデーセールを開催。',
#   'AppleのHypervisorフレームワークとQEMUを利用し、Apple M1チップ搭載のMacで「Windows ARM64 Insider Preview」の仮想化に成功したユーザーが現れる。',
#   'Intel Stock May Have Hit Rock Bottom. How to Position for a Rally.',
#   'This Is Where We Are',
#   "Here's One Way To Buy Apple Stock Ahead Of A Potential Breakout",
#   "Is Netflix Stock A Buy Right Now? Here's What IBD Charts Show",
#   'Job Growth May Have Hit A Wall',
#   "Dow Jones Rises, As Tesla Stock Hits Record High, This Hot IPO Surges Out Of New Buy Zone - Investor's Business Daily",
#   'Thinking about trading options or stock in Novavax, Tesla, AstraZeneca, Apple, or Moderna?',
#   'Thinking about trading options or stock in Novavax, Tesla, AstraZeneca, Apple, or Moderna?',
#   'Stocks making the biggest moves in the premarket: AstraZeneca, Disney, Pfizer, Amazon & more',
#   "Dividend Investing Isn't Dead Even If Growth Is Explosive",
#   'The Time To Worry About Tomorrow Is Today',
#   'Company Close Updates: International Business Machines Corp. stock rises Friday, still underperforms market',
#   'Company Close Updates: Alphabet Inc. Cl A stock rises Friday, outperforms market',
#   'Company Close Updates: Apple Inc. stock rises Friday, still underperforms market',
#   'Company Close Updates: Fitbit Inc. stock falls Friday, underperforms market'],
#  ['iOS 14のiPhoneで利用可能なウィジェットはmacOS 11 Big SurのApple Silicon Macでも利用可能。',
#   'UnclutteやDefault Folder X、DaisyDisk、ForkLift 3など合計9アプリ272ドル相当が78%OFFの59ドルとなる「Macnificent 9」セールが開催中。',
#   'Why Stocks Are Likely Headed Higher Into Year-End',
#   "Google's Super App Wakeup Call",
#   '10 most searched shares in Australia',
#   'To MBA or not to MBA as an MD: a physician’s journey',
#   'BST: Enjoying Monthly Income - Attractive Growth, Too',
#   'Feature: 10 Stocks to Be Thankful for This Thanksgiving',
#   'Stockstowatchtoday Blog: The S&P 500 Could Jump 20% Next Year. Three Strategists Explain Why.'],
#  ['Dow 30,000: How the market rally defied a pandemic',
#   'Strong holiday demand for AirPods could continue into 2021, analyst says',
#   'Apple Seeks Patent For Windshield Crack Detection Tech - Benzinga',
#   'Autotrader: Which is better? The Subaru Crosstrek vs. the Hyundai Kona',
#   'Need to Know: The Dow just hit 30,000. Keep betting on stocks, one strategist says',
#   'Rally On Pause Ahead Of Thanksgiving As Choppy, Light Trade Expected',
#   '3 Tech Stocks to Buy As the Nasdaq Makes a Comeback - InvestorPlace',
#   'Mac用Twitterクライアント「Tweetbot 3 for Twitter」がmacOS 11 Big SurとApple M1 Macをサポート。',
#   'Apple Is Caving Big Time',
#   'macOS 11 Big SurとApple Siliconに対応した画像圧縮ツール「ImageOptim」のBeta版が公開。',
#   'AgileBits、Universal BinaryでIntelとApple Siliconにネイティブ対応した「1Password for Mac」のBeta版を公開。',
#   'iShares Edge MSCI Min Vol: A Strategy That Makes Sense',
#   'Apple is making strategic moves to head off antitrust fights',
#   'MacBook ProのTouch Barにアプリ切替えボタン設置してくれる「TouchSwitcher」がmacOS 11 Big SurとApple M1チップに対応し、Touch Bar表示の上書き機能を強化。',
#   '3 Blue Chip Stocks to Buy Heading into 2021',
#   'Top Analyst Upgrades and Downgrades: Analog Devices, Apple, Best Buy, Dell, Dollar Tree, Fastly, GE, GM, HP, Medtronic, Zscaler and More',
#   'Dow Jones Today Dips, Nasdaq Futures Rise Ahead Of Jobless, GDP Data; China Investigation Hammers E-Auto Stocks',
#   'Dow 30,000: Morning Brief',
#   'Big List of Free Stocks For New Commission-Free Brokerage Apps',
#   'Is Wells Fargo Stock A Buy As Warren Buffett Continues To Cut Stake?'],
#  ['iPhone 12 Pro Max, iPhone 12 mini driving stronger demand in December quarter',
#   "Morningstar's top stock pickers say these are the 10 highest-conviction stocks they recommend — and which top fund managers recently piled their money into",
#   'Apple Inc. (AAPL): Are Hedge Funds Chasing Momentum Stocks?',
#   'Lookback: Wedgewood Partners 2019 Apple Inc (AAPL) Thesis',
#   'Best Buy Blasts Q3 Earnings Forecast, Holds Back on Guidance',
#   'デジタルスクラップアプリ「Pixave for Mac」がmacOS 11 Big SurとApple Silicon、WebPをサポート。',
#   'Parallels、Intel Macに対応した「Parallels Desktop 16 for Mac」の新規/アップグレードライセンスを20%OFFで販売するブラックフライデーセールを12月2日まで開催。',
#   'Zoom、macOS 11 Big SurにアップグレードしたMacでバーチャル背景使用時にCPU使用率が高くなってしまう不具合を修正した「Zoom for Mac v5.4.4」をリリース。',
#   "Science Is Winning: Cramer's 'Mad Money' Recap (Monday 11/23/20)",
#   'HBO Max And ‘Wonder Woman 1984’: Testing And Learning In Media Distribution',
#   'The Technical Indicator: Charting a bullish technical tilt: Dow 30,000 and Nasdaq 12,000 under siege',
#   "S&P Inclusion And Tesla's Future",
#   'The Payments King Is Dead. Long Live The New King.',
#   'Final Market Comments (Goodbye To Seeking Alpha)',
#   'Lumentum Holdings Remains Optimistic Despite Encountering Some Headwinds',
#   "Earnings would've been up in Q3 if it weren't for three industries: Morning Brief",
#   '13Fs Reveal Players Hiding In Polite Paper, Gold, Pharma',
#   "What Is A Company's Intrinsic Value?",
#   "Dow Jones Jumps 500 Points, As Trump Agrees To Biden Transition; Nio, Tesla Race To New Highs - Investor's Business Daily",
#   'Why the ResApp (ASX:RAP) share price is edging higher'],
#  ['The Tell: Here are the top ‘high-conviction’ buys for Q3 from star stock-pickers according to Morningstar',
#   'AAPL: Forget Apple, Buy These Faster-Growing Tech Stocks Instead - StockNews.com',
#   'NerdWallet: What to buy and what to skip this Black Friday',
#   'Autotrader: The best cars for your holiday road trip',
#   'Native InstrumentsやPioneer DJ、Seratoが、Apple M1チップ搭載のMacとDJコントローラー/アプリの対応状況を公開。',
#   'Serif、Mac/iPad/Win対応のデザインツールAffinity Photo、Designer、Publisherおよび公式ストアの全てのコンテンツを30%OFFで販売するブラックフライデーセールを開催。',
#   'Apple, Microsoft Work Together To Bring Xbox Series X Controller Support For iPhone, iPad - Benzinga',
#   'PSD3: Lessons To Learn From US Visa Lawsuit',
#   'Goldman Sachs analyzed 814 hedge funds. These are 15 stocks portfolio managers love and hate the most right now.',
#   "Dow Jones Surges More Than 300 Points, Led By Boeing, Walt Disney, Chevron; What's Wrong With Apple Stock?",
#   'Small Caps Record A New High, Finally, With More To Come',
#   'Apple Shares Up 60%, Await More iPhone 12 Data',
#   'Pioneer Investments Cuts Amazon, Apple',
#   "Disney's Earnings Beat Estimates, But Questions Remain",
#   'Dow Jones Leads As Stock Market Trims Gains; Apple Falls But Tesla, Nio Surge',
#   'International Developments Favour Tencent',
#   'How I Would Invest $1 Million',
#   'Dow Jones Futures: Latest Bitcoin Play In Buy Zone As Tesla, Nio, Xpeng Fly; Apple Stock Breaks Support',
#   'Overbought Indicators Are Good Signs To Take Profits On A Trade, But Not To Enter Shorts',
#   'Thinking about trading options or stock in Apple, Merck, Solaredge Technologies, Roku, or Norwegian Cruise Line?'],
#  ['macOS 11 Big SurにはIntelプロセッサを前提として開発されたアプリやAudio UnitプラグインをApple Silicon Macで実行できるようにする「Rosetta2 Updater」が導入。',
#   'Hazelton Capital Partners 3Q20 Commentary',
#   'Dow Jones Futures: Qualcomm Near Buy Point In Tight Stock Market Rally; Apple Looks Tired',
#   'Biden Will Normalize Chinese Relations And Collaborate On Climate And Trade',
#   'DTD: I Am Maintaining My Neutral Outlook For 2021',
#   'The Dow Industrial Price-Weighting Design Skews Performance'],
#  ["Apple Is Trying To 'Water Down' Bill Against Forced Labor In China: Washington Post",
#   'Twitter、macOS 11 Big SurとApple Silicon Macに対応した「TweetDeck by Twitter v3.17」をリリース。',
#   'Apple、IntelとApple SiliconのUniversal Binaryに対応したSFフォント派生のベクターシンボル「SF Symbols 2.1」をリリース。',
#   'Stock Market Rally Holds Tight; Qualcomm Near Buy Point; Apple, Microsoft, Amazon Look Tired',
#   "All of Tesla's other services will be worth more than its car business, according to one Wall Street analyst who says the company should be compared to Apple, Tinder, and more. (TESLA, AAPL, ROKU, MTCH)",
#   'These “Hidden” Funds Will Give You Both Income And Safety In 2021',
#   'FB Stock Has New Buy Point In Bullish Base; Facebook Navigates Antitrust, Coronavirus News',
#   'Company Close Updates: Best Buy Co. Inc. stock rises Friday, outperforms market',
#   'Company Close Updates: Autodesk Inc. stock falls Friday, underperforms market',
#   'Company Close Updates: Xerox Holdings Corp. stock remains steady Friday, still outperforms market',
#   'Company Close Updates: CDW Corp. stock outperforms market despite losses on the day',
#   '5 Best CEFs To Buy This Month (November 2020)',
#   'Market Watch: Retail Investors Pour Money Into China Funds'],
#  ['Apple will pay $113 million over investigation into slowing iPhones',
#   'Apple, Verizon Join Hands To Encourage Enterprise Upgrade To 5G, iPhone 12',
#   ': ‘Goldilocks’ funds? Midcap ETFs may be about to have their moment',
#   'VMware、macOS 11 Big Surとの互換性を向上させWindows 10 20H2やUbuntu 20.10をサポートした「VMware Fusion 12.1 for Mac」をリリース。',
#   'OWC、macOS 11 Big SurへアップグレードされたThunderbolt 3/Apple M1のMacでThunderbolt 4ポートを3つ搭載した「OWC Thunderbolt Hub」の互換性を確認。',
#   'Stock Picks: Find The Best Growth Stocks To Buy With Lessons From Nvidia, Apple, Veeva',
#   'Apple will pay $113 million over investigation into slowing iPhones - Fox Business',
#   'Roku Stock Hits Record High On Possible HBO Max Carriage Deal',
#   'CodeWeavers、Apple Silicon MacとRosetta 2を利用してx86アプリを実行できるWindows互換レイヤー「CrossOver 20 for macOS」を開発中。',
#   "Here's My Tech Rundown, Brazilian-Style - RealMoney - RealMoney",
#   'Market Seems Torn Between Vaccine Optimism, Worries About Virus, Stimulus, Fed Lending',
#   'The Mall Isn’t Dead. Why It’s Time to Go Shopping for Simon Property Stock.',
#   "What we're witnessing is the start of 1929 with a nuclear warhead attached to it",
#   'This Top-Performing Mutual Fund Shuns Apple, Facebook, Netflix',
#   "Dow Jones Falls Amid Coronavirus Restrictions, Covid-19 Vaccine; Nio, Tesla Eye Record Highs - Investor's Business Daily",
#   'Best-In-Class S&P 500 ETF: Look To Vanguard For Top Indexed Returns',
#   'The Complete Berkshire Hathaway Portfolio',
#   'Sometimes You Need to Change Lanes to Stay on the Right Track',
#   "Apple (AAPL) Reaches Settlement Over iPhone 'Batterygate'",
#   'Understanding The Current Price And Potential Of Alphabet (3 Types Of Valuation + Bonus)'],
#  ['The Wall Street Journal: Nvidia to bring ‘Fortnite’ back to iPhones amid Epic’s app store fight',
#   "Healthy demand suggests iPhone 12 'supercycle' is underway, analyst says",
#   'Apple Silicon搭載のMacでハードウェア診断「Apple Diagnostics」を使う方法。',
#   'Parallels、いくつかのサードパーティアプリで発生していた不具合を修正したIntel Mac向け仮想化ソフトウェア「Parallels Desktop v16.1.1 for Mac」をリリース。',
#   'Holiday 2020 - Our First True OmniHoliday',
#   'Cable giant Malone praises new streaming gatekeepers: Amazon (AMZN), Apple (AAPL), Roku',
#   '3 Large-Cap Tech Stocks to Buy and Hold for Growth & Dividends',
#   'With Speculation In The Air Show Your Moxie, Tap Ragamuffins',
#   'The 737Max Is Returning And Will Be A Successful Aircraft',
#   'Top Dividend ETFs For November',
#   "Here's What $500 Invested In 7 Electric Vehicle Penny Stocks In March Is Worth Right Now",
#   'Sonos May Not Even Need Apple After Its Q4 Results',
#   "Thinking about trading options or stock in Apple, Coty, Tesla, Square, or Children's Place?",
#   'Chip Foundries on Track for 2020 Revenue Boost of 24%',
#   'Dow Jones Today, Futures Hover As Jobless Claims Rise; Sonos, Berry, Fiserv Eye Breakouts',
#   'One Easy Way To Beat The Market: Go Overweight XLK Vs. SPY',
#   "Thinking about trading options or stock in Apple, Coty, Tesla, Square, or Children's Place?",
#   'Western Digital: Not A Recovery Play, Now Or Later',
#   'Apple (AAPL) Slashes Commissions for Small App Developers',
#   'Global fund managers are bullish on these 3 things'],
#  ['App Store fee reduction will have limited impact on Apple, says JP Morgan',
#   "Apple One could bolster Services, while 2020 iPhone sales growth remains 'mixed picture'",
#   "App Store fee program will have 'immaterial' effect on Apple, says Morgan Stanley",
#   'Healthcare App Development Company',
#   'Pixelmator Team、Apple Silicon MacとmacOS 11 Big SurをフルサポートしたMac用グラフィックアプリ「Pixelmator Pro v2.0」をリリース。',
#   'AgileBits、macOS 11 Big Surに最適化され、Apple Watchでのアンロックに対応した「1Password for Mac v7.7」をリリース。',
#   '2 Great Dividend Stocks Whose Payouts Could Double',
#   'Always-on Processorが導入されたApple Silicon「M1チップ」搭載のMacBook Air/Proではスリープという概念が無くなりつつある。',
#   'アプリがUniversal Binary化されているかをチェックできるユーティリティ「Uni Detector」がIntelとPPCに加えApple Siliconバイナリのチェックに対応。',
#   'No Checking Out Of The Hotel California While Markets Are Addicted To Central Bank Money',
#   'Look Past The Lie: Wall Street Is Not Going Gangbusters',
#   "Dow Jones Today Nears 44-Year Record; Futures Rise On Pfizer Vaccine News, Boeing's 737 Max Set To Fly",
#   'Top Stocks To Short Today As Vaccine And Boeing News Sends Markets Higher',
#   'Apple: Trust The Process',
#   'What Programming Language Should Business People Learn?',
#   "SoftBank billionaire Masa Son is stockpiling cash for a 'worst-case scenario'",
#   'What Apple’s App Store Fee Change Doesn’t Do',
#   'Top Buys From The Best Money Managers (Q3 2020)',
#   'What to watch today: Dow set to resume its rally',
#   'RSP: Equal Weight Has Been Winning, It May Be Prudent To Stick With It'],
#  [': Apple products worth nearly $7 million stolen in highway robbery',
#   "Apple's Big Sur Woes See No End As Older Mac Users Report Glitch",
#   'Mark Hulbert: Momentum stocks may get an end-of-the-year push, history shows',
#   'Di-Worsification: Why Investors Should Avoid Over-Diversifying Their Portfolios',
#   "Warren Buffett Stocks: What's Inside Berkshire Hathaway's Portfolio?",
#   "Apple's Big Sur Woes See No End As Older Mac Users Report Glitch - Benzinga",
#   'For S&P 500, Tesla Inclusion Is A Risk',
#   'Adobe、Apple Silicon Macに対応した「Photoshop for Mac ARM」のBeta版を公開。',
#   "Should Apple Investors Panic Over Buffett's $4 Billion Sale?",
#   'Apple Silicon MacではIntel/Apple Siliconに対応したUniversal 2アプリでもRosetta 2を利用してIntelバイナリで起動することが可能。',
#   'Warren Buffett Buys 6 Stocks In 3rd Quarter, Dumps Costco',
#   ': ‘Don’t let COVID fatigue trick you’: How to survive winter as the pandemic rages on',
#   'Bitcoin Price Heads For All-Time High',
#   'NADA Chairman Lashes Out At Automakers Over ‘Mausoleum Mandates’',
#   'Apple MacBook Pro 13-inch review: How the new M1 chip stacks up to Intel’s',
#   'Impressive Earnings From Walmart, Home Depot, Apparently Not Impressive Enough To Lift Market',
#   'Volkswagen Has Sold 359x As Many Id.3s As Tesla Has Sold Model 3s In The Netherlands In November And 112x As Many In Norway',
#   'Autotrader: Review: 2021 is a big year for the Mercedes-Benz E-Class',
#   'Warren Buffett Makes Monumental Changes in Bank, Pharma, Tech Stock Holdings',
#   'Hon Hai Precision: iPhone Contract Manufacturer To Face New Competition'],
#  ['Warren Buffett sells 36M Apple shares, picks up major drug stocks',
#   'Market Extra: Dow on verge of 30,000 and first record close in 10 months on back of Apple’s stock surge',
#   ': Apple has been hit with privacy complaints from the same digital activist who successfully took on Facebook',
#   'AAPL: Forget Apple, Buy These 3 Tech Stocks Instead - StockNews.com',
#   'Mobile App Development Company in Saudi Arabia',
#   'Dow Jones Futures: Apple, Disney Lead 5 Dow Stocks Near Buy Points For Coronavirus Vaccine Market',
#   'Warren Buffett Was A Big Buyer Of Drug Stocks In Q3, Including Covid Vaccine Developer',
#   'Edge Computing Is Leading The Next Great Tech Revolution',
#   "Dow Jones Soars 400 Points On Effective Moderna Coronavirus Vaccine; JD.com Dives On Earnings - Investor's Business Daily",
#   'Lululemon: An Expensive Top Apparel Play',
#   'SPYG: Growth Will Stagnate As Value Takes Over',
#   "Warren Buffett's Berkshire Hathaway makes big bets on drug stocks",
#   'QYLD: A Fund For Damage Control',
#   'TECL: Using 3x Super Leveraged Tech Focused ETF For Actionable Options Plays',
#   'PlayStation 5 Might Outsell New Xbox Series But Gaming Subscription Service Gives Microsoft An Edge, Analysts Say - Benzinga',
#   'Warren Buffett Buys 6 Stocks in 3rd Quarter, Dumps Costco',
#   'Who Should Avoid Maritime Shipping',
#   'Dow Jones Futures: President Trump Defiant After Hinting At Concession; JD.com Earnings Due As Coronavirus Cases Soar',
#   'Hedge Funds Are Betting Big On This $130 Trillion Trend',
#   "Is Intel Stock A Buy Right Now? Here's What IBD Charts Show"],
#  ['macOS 11 Big SurではNetstatやPing、Lookup、Traceroute、Whois、FingerコマンドをGUIで行える「ネットワークユーティリティ」が廃止。',
#   'Why Higher Treasury Yields Will Boost Stocks',
#   'The Strange Inability Of The Tech Stock Indexes To Get Going',
#   'macOS 11 Big SurではAFP over TCP/IPを使用したファイル共有が廃止され、SMBでのファイル共有のみに。',
#   'How To Make $4,000 Monthly From These High-Yielders',
#   'How To Invest Like Warren Buffett',
#   'Sand In My Shoes - October Update',
#   'Covid-19: As lab execs sell shares worth millions, questions arise - msnNOW',
#   'Stock Market Rally At Highs, With Google, JD.com, Moderna Coronavirus Vaccine In Focus; What You Should Do By Monday',
#   '(2020.11.16) (various)',
#   '(Trendmicro)モaaS 竇繙吾⒢11/20 篋 11 ...',
#   '(Impress Watch, 11/13)ホ95 後⒢⒢罔≧ 。潟 ...',
#   'с障ゃパFalcon 9 ＞ 絎障㏍ ISS 亥13 絎с ...',
#   "Cirrus' Quiet - Well, Maybe Not So Quiet - March Forward",
#   "The Retirees' Dividend Portfolio: John And Jane's October Taxable Account Update"],
#  ['The Wall Street Journal: Mercer-backed Parler makes ‘free speech’ pitch to conservatives mad at Facebook and Twitter',
#   'Millions Of Google Chrome Users Are Suddenly Making A Surprising Switch Because Of One Critical Feature',
#   'Twitter、macOS 11 Big Surに最適化した「Twitter for Mac v8.43.11」をリリース。Apple Silicon Macへの対応も進行中。',
#   'macOS 11 Big SurではPowerPCからIntelへ移行したMac OS X時代と同じく、Finderやシステム情報からIntel/Apple SiliconのUniversal2対応アプリを確認可能に。',
#   'Native Instruments、macOS 11 Big SurへアップグレードしたMacでDJコントローラを使用すると誤作動によりコントローラが損傷したりCPUに高負荷が発生するとして警告。',
#   'These Are The 5 Best Stocks To Buy And Watch Now',
#   'This 7.2% Dividend Is A Smart Buy For A Biden Presidency',
#   "'The most dangerous type of market': Billionaire Bond King Jeffrey Gundlach says stocks are entering the difficult final stages of their cycle — and warns the market will 'crack pretty hard' in the near future",
#   "Benzinga's Bulls And Bears Of The Week: Apple, Disney, Tesla And More",
#   "Want Safe Income? Here's How To Invest",
#   'Mercer-backed Parler makes ‘free speech’ pitch to conservatives mad at Facebook and Twitter',
#   'Company Close Updates: Best Buy Co. Inc. stock rises Friday, still underperforms market',
#   'Company Close Updates: CDW Corp. stock rises Friday, outperforms market',
#   'Company Close Updates: Xerox Holdings Corp. stock outperforms competitors on strong trading day',
#   'Feature: Your ESG Portfolio Could Have Too Much Tech Exposure. Here’s How to Fix It.',
#   'Sectorfocus Blog: U.S. Election Results and China Moves Bode Well for Tech, Wedbush Says',
#   'The Trader: Target Is Booming During the Pandemic. Why the Stock Still Looks Undervalued.',
#   'Features - Main: A Covid Vaccine Is Coming. Here’s What It Means for the Stock Market.',
#   "Barron's Cover - Main: Intel Has Fallen Behind Rivals and the Rest of Tech. Why Its Stock Can Rise Again."],
#  ['Peter Lynch disciple William Danoff manages over $124 billion and has beaten the market for 30 years. He shares the 10 investment rules that ensured his success.',
#   'Final Cut ProやCompressor、Motion、Logic Pro、iMovie、GarageBandがApple Silicon Macに対応。',
#   'Apple、macOS 11 Big Surに最適化されIntelとApple Siliconでネイティブ動作するUniversal Binaryとなった「iWork for Mac」をリリース。',
#   'PFUのScanSnapやHHKB各機種がmacOS 11 Big Surに対応。',
#   'RSSリーダー「Reeder 5 for Mac」がmacOS 11 Big Surのウィジェットに対応。',
#   'Adobe、macOS 11 Big SurとIntel/M1プロセッサを搭載したMacで発生しているPhotoshop/Lightroomの既知の不具合を公開。',
#   'Apple、Google Project Zeroにより報告された3件のゼロデイ脆弱性を修正した「セキュリティアップデート 2020-006」をmacOS Mojave/High Sierra向けに公開。',
#   'Buy and Hold this Tech Stock for Long-Term Gains',
#   'Incoming White House chief of staff Klain has ties to tech world - MarketWatch',
#   'Apple iPhone 12 review: Which one should I buy?',
#   '3 Strong Stocks to Buy for the Second Half of Q4 and Beyond',
#   'Boardwalk: Our Resident Undervalued REIT',
#   'Top Tech Stocks For November',
#   'Paradox Interactive Has A Grand Strategy',
#   "Dow Jones Rallies 250 Points, As Disney Jumps On Earnings; DraftKings, Tesla Rival Li Auto Soar - Investor's Business Daily",
#   'Skyworks Solutions: Lifted By A 5G Revolution',
#   '3 Reasons to Buy Apple Stock Right Now',
#   'Should you invest in Applied Materials, Xpeng Inc, Ross Stores, Apple, or American Airlines?',
#   'Tinybeans (ASX: TNY) share price leaps 9% after record month',
#   'Best Internet of Things (IoT) Stocks for 2021 - Money Morning'],
#  ['Apple supplier Foxconn posts $1.1 billion quarterly profit; beats estimates - Reuters India',
#   ': Some of the biggest tech names just called on the EU to step up antitrust actions against Google',
#   'Apple supplier Foxconn Q3 profit near flat, beats estimates - Fox Business',
#   'Microsoft、Rosetta 2を利用しApple Silicon Macをサポートした「Office 2019 for Mac v16.43」をInsider向けに公開。',
#   'Serif、macOS 11 Big SurとApple M1に最適化した「Affinity Designer、Photo、Publisher v1.8.6」をリリース。',
#   'Anker Japan、USB-C充電ポートやBluetooth 5.0、アプリに対応したIPX7防水のコンパクトなBluetoothスピーカー「Anker Soundcore Mini 3」を発売。',
#   'Apple、macOS 11 Big Surのリリースを前にゼロデイ脆弱性を修正した「macOS 10.15.7 Catalina Build 19H15」のインストーラーアプリを公開。',
#   'Even Multi-Bagger Stocks Aren’t Immune To Major Drawdowns, Research Shows',
#   'Apple、macOS 11 Big SurにmacOS 10.15 Catalinaと同じPython 2.7.16やRuby 2.6.3p62などを同梱してリリース。',
#   'Wall Street Favoring Stay-At-Home Trade As Virus Cases Mount And Vaccine Still A Ways Away',
#   'For The Stock Market, The Election Isn’t Nearly Over',
#   'Dow Jones falls 200 points despite better-than-expected U.S. jobless claims',
#   'Sonos Takes A Step Forward In Internet Radio With SuperHiFi’s AI Technology',
#   'Dude, Where’s My Car Keys?',
#   '100 billion reasons Apple should get behind Bitcoin: Michael Saylor',
#   "Tracking Ken Fisher's Fisher Asset Management Portfolio - Q3 2020 Update",
#   "Dow Jones Near Session Lows As Stocks Stall; No Stimulus Deal Yet, Trump Digs In - Investor's Business Daily",
#   "Europe is coming for Big Tech. Biden's victory won't change that",
#   'A Mixed Bag Of Indicators For Investors',
#   'Apple (AAPL) Introduces Mac With Its Own M1 Chip'],
#  ["Here's what analysts thought about the Apple Silicon announcements",
#   'Equilibrium Descends on Mixed Market Indexes: AAPL, DIS & More',
#   'Need to Know: Goldman Sachs has just boosted its S&P 500 target. Here’s why',
#   'MarketWatch First Take: Apple’s new Macs launch in time for holidays, but shouldn’t make your wish list',
#   'When Will Apple Finally Be a Buy? - TheStreet',
#   'Amazon、iOS 14/iPadOS 14のウィジェットをサポートした「Kindle for iOS v6.36」をリリース。',
#   'Primate Labs、Apple Silicon MacのネイティブパフォーマンスとRosetta 2を利用したパフォーマンス測定に対応したベンチマークアプリ「Geekbench v5.3」をリリース。',
#   'Anker Japan、Lightning端子を直角にすることでiPhoneの充電中でも快適にゲームをプレイできるMFi認証のLightningケーブル「Anker PowerLine Play 90 ライトニングケーブル」を発売。',
#   'Stock Market Today: Big Tech Bounces Back',
#   'Stocks Trade Higher as Tech Shares Post Sharp Rebound - TheStreet',
#   'Apple is taking control, and a risky bet, with its M1 chip',
#   'Apple M1チップを搭載したMacで動作する「Parallels Desktop for Mac」は現在開発中で、近くTechnical Previewを公開。',
#   'Autotrader: The 2021 Ford Mustang: There’s good news and bad news',
#   'How Adrian Gonzalez Conquered Business After Baseball',
#   'Fans In Limited Capacity Will Be Allowed In Arena For OKC Thunder Home Games During 2020-21 Season',
#   'Stock Market Today: Big Tech Bounces Back',
#   'Top Tech ETFs For November',
#   'CyberArk: Business Model Transition Hurts',
#   "Dow Jones Jumps 150 Points, As Tech Stocks Snap Back; Datadog Plunges 13% On Earnings - Investor's Business Daily",
#   'Singles Day: Alibaba sales blitz set for record haul as Chinese shake off Covid-19'],
#  ['Stock Market Today With Jim Cramer: Apple Event Preview - TheStreet',
#   "Apple unveils the new $999 MacBook Air, its first laptop running Apple's homemade chip (AAPL)",
#   ': Amazon has been hit with antitrust charges from the EU and faces investigation into Prime',
#   ': Amazon’s EU troubles could be warm-up act for more regulatory actions vs. Big Tech',
#   'The Tell: He bought Tesla and Apple in 2013 — now he’s got $5.4 million and is asking the internet what to do with it',
#   'Stock market news live updates: Stock futures mixed as vaccine euphoria abates, tech selling continues - Yahoo Canada Shine On',
#   'Need to Know: Here are the 2 big signals that stocks need to keep moving higher, says Credit Suisse’s top equity strategist',
#   '1 Click To Squeeze An 8.2% Dividend From Apple',
#   'Apple、8コアCPU/GPUやThunderbolt/USB 4コントローラ、Secure Enclaveを統合した5nmプロセスのMac用SoC「M1」を発表。',
#   'Go Out Or Stay At Home: “Reopening” Stocks Could Come Back To Earth As Vaccine Timing Eyed',
#   'MacDailyNews presents live coverage of Apple’s ‘One more thing’ special event',
#   'Apple、M1チップを搭載し2つのUSB-AとThunderbolt/USB 4ポート、HDMI 2.0、Gigabit Ethernetポートを搭載した「Mac mini」を発表。',
#   'Anker Japan、最大30WのUSB-C PDポートを搭載した電源タップ「Anker PowerPort Strip PD 3」と「PowerPort Strip PD 6」の販売を開始。',
#   'Apple、iPhoneのApp StoreでmacOS 11 Big Sur搭載のApple Silicon Macで動作するiOSアプリの互換性情報を表示開始。',
#   'Apple announces its first-ever M1 processor, coming to MacBooks and Macs',
#   'LIVE: Apple to reveal the first MacBooks to run on Apple silicon, signaling a big change for the Mac (AAPL)',
#   'The Technical Indicator: Charting market rotation: S&P 500, Dow industrials challenge record highs',
#   '2 Biden-Friendly REITs To Buy Today',
#   "Dow Jones Futures: Apple, Microsoft Lead Stocks For Coronavirus Vaccine Or Pandemic Stock Market Rally - Investor's Business Daily",
#   '7 High-Yield Dividend Stocks to Buy Instead of Bonds'],
#  ['Apple Silicon switch could lead to lower-cost Mac lineups, analyst says',
#   ': As Apple releases its new line of Macs, the biggest beneficiary may be Microsoft',
#   ': A strong year-end rally lies ahead. It’s time to rotate ‘within the tech sector’ — away from FAANG stocks, strategist says.',
#   'Apple’s New Era Has Begun',
#   'Wall Street Legend Bill Miller ‘Strongly’ Recommends Bitcoin',
#   'macOS 11 Big SurとApple Silicon Macに対応したGitクライアント「Tower for Mac v6.0」がリリース。',
#   'Anker Japan、GaNを採用し18mmの薄さで最大45Wと18W出力のPPS規格対応USB-Cポートを備えた急速充電器「Anker PowerPort Atom III 63W Slim」を発売。',
#   "Apple 'One More Thing' Mac event: What to expect",
#   'Profiting From Trading Stocks Of The S&P 500 Consumer Discretionary Sector',
#   'ASE Technology: Value Investing In The Future',
#   'ADX: Positive Returns, Looking Forward To A Year-End Special Dividend',
#   'Replacing LIBOR',
#   'What to watch today: Dow set to rocket higher on Covid vaccine trial data showing 90% efficacy',
#   'TD Ameritrade Investor Movement Index: IMX Score Remains Nearly Flat in October',
#   "Dow Jones Futures: After Huge Stock Market Rally, Biogen Is Set To Dive; Do This Before Monday's Open - Investor's Business Daily",
#   'Apple (AAPL) Taking Orders for iPhone 12, HomePod Mini',
#   "It's Tanger Time: Will Santa Deliver?",
#   "Dow Jones Futures: After Huge Stock Market Rally, Biogen Set To Dive; Tesla, Nio, Xpeng Rise - Investor's Business Daily",
#   'Replacing LIBOR',
#   'Profiting From Trading Stocks Of The S&P 500 Consumer Discretionary Sector'],
#  ['Morgan Stanley Is Making Some Big Moves',
#   'Benzinga Survey: Will Apple Or Microsoft Stock Grow More By 2025?',
#   'Berkshire Hathaway Seems To Have Learned Something From Its Largest Holding',
#   'Should You Invest in the Invesco DWA Technology Momentum ETF (PTF)?',
#   'Stock futures rise after Biden-Harris win, McDonald’s and Disney in focus - Fox Business',
#   'Stock market news live updates: Stock futures open higher after Biden victory',
#   'Berkshire Hathaway Reports Q3 2020 Earnings',
#   'Top 4 Large-Cap ETFs for 2020',
#   'How Many Stocks Do You Need To Be Diversified?'],
#  ["Warren Buffett Doubles Down On Major Reversal In Investing - Investor's Business Daily",
#   'This “Buy The Dip” Strategy Is Perfect For 7% Monthly Dividends',
#   'Big Tech corporate counsel salaries revealed: How much Google, Amazon, and Apple are paying their lawyers (AMZN, GOOG, AAPL)',
#   'Stocks To Watch: Sports Betting Buzz, Alibaba And Safe Haven Plays',
#   'Gold Investors Might Soon See A Price Of $2,500 Per Ounce',
#   'Tandem Diabetes Care: Pump Provider Trailing Insulet But Shares Have Growth Potential',
#   'Feature: Berkshire Buybacks Hit Record $9 Billion in Third Quarter. Operating Earnings Miss Mark.',
#   'Dividend Challenger Highlights: Week Of November 8',
#   '5 Safe And Cheap Dividend Stocks To Invest In (November 2020)'],
#  ['Judge allows lawsuit from AAPL investors over ‘credible’ claims of being misled',
#   'Supply chain seeing stronger than expected iPhone 12 holiday quarter demand',
#   "FAANG stands for five very successful tech companies that can move the stock market — here's what to know about investing in them",
#   'Need to Know: Time to move on? Here’s one investor’s advice on what to do after the election',
#   'Qualcomm, Skyworks: Apple Suppliers Already Gaining Big From iPhone 12',
#   'Kensington、AppleのMagic KeyboardやMouse、Trackpadにもマッチしたグレーカラーの「ErgoSoft リストレスト」シリーズを日本でも販売開始。',
#   'Apple Stock Bulls Could Be Very Disappointed This Year',
#   'Autotrader: The 2021 BMW 8 Series: High style, high luxury, great power',
#   'Pluto TV Grabs 36 Million Global Users, Doubles Ad Revenue Amid Weaker Q3 For ViacomCBS',
#   'Tech Leadership Reflects Earnings Power',
#   "Apple's HomePod Mini is so popular that shipping dates are already being pushed back (AAPL)",
#   'As Covid-19 Explodes, America’s Entertainment And Sports Industries Implode',
#   "How To Trade Apple Options Ahead Of 'One More Thing' Event",
#   'Nautilus: Uncertain Outlook Weighs On Future Growth',
#   'Biden’s Lead Is Bittersweet For America’s\xa0Allies',
#   'Novo Nordisk to boost pill-form diabetic drugs with $1.8 billion deal',
#   'Electronic Arts Skids 7% On Weak Outlook, Declares First-Ever Dividend',
#   'This\xa0$9.5 Billion Takeover Offer\xa0Looks Too Good to Refuse',
#   "Jack Ma's Ant Group IPO Faces Delay Of Over Six Months: FT",
#   'US STOCKS-Futures slip after strong Wall St rally as Biden edges closer to White House'],
#  [': Apple could face shortage of critical chips for its new iPhones: report',
#   'Autotrader: How does the Toyota C-HR compare with the Subaru Crosstrek?',
#   ': Qualcomm’s fortune turns as the chipmaker’s 5G business grows rapidly',
#   'Dow rallies 463 points on gains for shares of Caterpillar, Apple Inc. - MarketWatch',
#   'Stock Market Today: Stocks Soar on Status Quo',
#   'October Crypto Recap: PayPal Embraces Bitcoin, Institutional Adoption, Central Bank Digital Currencies',
#   'Stock Market Today: Stocks Soar on Status Quo',
#   'Top Stocks To Short Today As Post-Election Rally Continues',
#   'A Contrarian Move For 8.8% Dividends, Fast Upside',
#   'Exxon Mobil, Not Facebook, Is Trailer Trash',
#   'Stocks May Not Care Who Wins The White House',
#   'Qualcomm: Long Awaited Step-Up',
#   'Investors Cheer Gridlock Potential That Could Prevent Tax, Tech, Health Care Overhauls - Benzinga',
#   'All-or-Nothing Bet\xa0on Bristol Drugs Goes Sour as FDA Reviews Lag',
#   "Ferrari N.V. Just Beat Earnings Expectations: Here's What Analysts Think Will Happen Next",
#   '3 Dividend Technology Stocks With Yields Of 2.5% And Up',
#   'Aphria, Anticipating Fed Legalization, Enters US Via $300M StreetWater Deal',
#   'Top Growth ETFs For November',
#   'Stocks making the biggest moves in the premarket: General Motors, Cigna, Merck, Regeneron & more',
#   'Investors Seem To Focus On Prospects For Gridlock Rather Than Continued Presidential Uncertainty'],
#  ['AAPL and other tech stocks up in possible response to election uncertainty',
#   'Spotify Rolls Out Standalone Streaming On Apple Watch App: TechCrunch - Benzinga',
#   'The Ratings Game: Software stocks rocket higher as divided government could put corporate tax hikes off the table, analyst says',
#   ': U.S. formally exits Paris climate pact even as it remains globe’s second-greatest polluter',
#   'Project Syndicate: Breaking up Google and the rest of Big Tech wouldn’t be enough to fix our innovation problems',
#   'Tech Soaring And Volatility Ebbing Early Despite Election Results In Holding Pattern',
#   'Bombich Software、macOS 11 Big Surに対応したバックアップユーティリティ「Carbon Copy Cloner v5.1.22」をリリース。SSVのバックアップについてはAppleと協議中。',
#   'Business Is Still Good for Skyworks, Cirrus and Other Mobile Chip Suppliers - RealMoney',
#   'Big Tech is still in trouble regardless of whether Trump or Biden wins',
#   'Top Stocks To Short Today As Markets Gain Amid Election Hopes',
#   "Dow Jones Surges 600 Points, While Tech Stocks Soar Despite Unclear Election Results - Investor's Business Daily",
#   'Big Tech shares soar as fears of a blue wave stoking antitrust probes subside',
#   "Big Tech Stocks Climb As Blue Wave Doomed, Easing Antitrust Woes - Investor's Business Daily",
#   'Tech Stocks Surge With Apple Leading Gains, But Wall Street Cautious in Election Deadlock - TheStreet',
#   'Why Big Tech Leaders Are Billed as the Top Election Winners',
#   'Top Stocks To Buy Today As Election Sets Markets Up For Another Surge',
#   'Daily Gold News: Gold is Volatile, but Still at $1,900',
#   'President Trump and Biden give very different speeches as election 2020 drags on',
#   "Dow Jones Futures: Investors Hail Election Results With Decisive Stock Market Rally; Google, JD.com Lead 8 New Breakouts - Investor's Business Daily",
#   'Thinking about trading options or stock in Cigna Corp, Apple, Alibaba, Synopsys, or General Electric?'],
#  ['App Store continues growth as potential larger business risks for Apple loom',
#   'The Wall Street Journal: Comcast is in talks with Walmart to develop and distribute smart TVs',
#   'Deep Dive: This single-country stock picker has beaten the S&P 500 over the past 10 years. His strategy can help you diversify',
#   'Mark Hulbert: You shouldn’t believe all this talk about a stock-market bubble about to burst — here’s why',
#   "3 Things You Should've Learned From Apple's Stock Split",
#   'ODS、Network Extensionの採用によりmacOS 11 Big SurとApple Silicon MacをネイティブサポートしたMac用ネットワークモニタリングアプリ「Little Snitch 5」をリリース。',
#   'Apple、2013年に発売された「iPhone 5C」と「MacBook Pro (Retina, 15-inch, Mid 2014)」をビンテージ製品に追加。',
#   "3 Stocks I'm Never Selling",
#   'Buy Roku Stock Before Earnings as Long-Term Streaming Investment?',
#   'This Utility Stock Could Give Your Portfolio A Spark',
#   '3 Large-Cap Tech Stocks to Buy Despite Market Uncertainty - Yahoo Finance',
#   'Amazon: Q3 2020 Results, Advertising Opportunity, Why The Stock Is Still Undervalued',
#   'Besides Alphabet, Big Tech Failed To Impress - Yahoo Finance',
#   'This Election, Vote CBOE Global Markets, Inc.',
#   'Don’t Pay Wells Fargo Specialized Technology Fund To Chase Momentum',
#   'The US dollar will remain weak no matter who wins the presidency',
#   'My Election Day Wish, Tech Sector Performance, Trading Amazon and 6 Other Stocks - RealMoney',
#   'Extreme Election Scenarios',
#   'Bitcoin’s closing price for October was its second highest ever monthly close',
#   'Forex trading online'],
#  ["Apple's Still Getting Punished on Wall Street for Not Selling Enough iPhones",
#   'Apple: Apple Is Still Buying Shares Of Itself And Is Still A Great Buy',
#   "'Closing Bell' Analysts Share Their Thoughts On Apple",
#   "'We think we're in the early stages of a bull market': Strategist",
#   'Laser Sensor Startup Aeva May See $2 Billion Valuation From NYSE Listing',
#   'Adjudicate Patents Properly In Their Proper Realm',
#   'Quarterly Review Of DivGro: Q3 2020',
#   'Asia Morning: Tech Stocks Lead US Market Lower Again - Action Forex',
#   'Dow Ends Higher Ahead of Election Day; Tech Drops and Recoups - TheStreet',
#   'Global Virtual Care Provider Physitrack Comes to Italy',
#   'Apple is holding another event next week, its 3rd product event in three months (AAPL)',
#   'China Market Update: Growth Stocks Driven Higher As Singles Day Kicks Off, Five Year Plan Lifts Electric Vehicles & Clean Energy',
#   'WisdomTree U.S. LargeCap Dividend Fund: Far From The Worst, But Not The Best',
#   'A Thematic Approach To Investing',
#   'Apple to hold Nov. 10 event, expected to bring new Macs with custom chips',
#   "Dow Jones Jumps 400 Points As Biden Lead Narrows; Software Stocks Lag, Amazon Hit Again - Investor's Business Daily",
#   "Dow Jones Jumps, Small Caps Lead As Trump Nears Biden Ahead Of Election - Investor's Business Daily",
#   '10 Stocks That Will Win If Joe Biden Wins the Election',
#   'Thinking about trading options or stock in Apple, Exxon Mobil, Beyond Meat, Royal Caribbean Cruises, or Boeing?',
#   "Dow Jones Jumps 500 Points But Apple Reverses; Tesla Races Higher, While Nio Surges 14% - Investor's Business Daily"],
#  ['This week’s top stories: iPhone 12 mini details, AirPods rumors, AAPL earnings, Apple One bundle',
#   'Earnings Watch: Companies try to avoid Election Day earnings, but there are still plenty of numbers coming',
#   'Apple Review: Ultimately, A Buying Opportunity',
#   'LAAC Technology: Five Advanced Django Tips',
#   'AppleのHardened RuntimeセキュリティとOWCやMicron、Transcendの最新のSSDを追加サポートしたMac用SMARTユーティリティ「DriveDx v1.10」がリリース。',
#   '3 Reasons Alphabet Surged on Friday While the Rest of FAANG Plummeted',
#   'Apple: Quarterly Numbers With A Perspective',
#   '5 Former SPACs That Are Now Penny Stocks Under $5',
#   'These Are The Four American Companies Worth Over $1 Trillion',
#   '5 Tech Dividends So Generous, You’ll Be Shocked',
#   'S&P 500 Weekly Forecast: Investor jitters into Election Day and what it means for stocks',
#   'Apple Review: Ultimately, A Buying Opportunity',
#   'Apple Q4 Results Unfairly Punished - Seeking Alpha',
#   'REITs Slammed As Lockdowns Sweep Europe']]

# %%
# Get second topic
trade_headlines, _ = get_headlines("trade")
# Out:
# Fetching news about 'trade'
# ******************************
# retrieving news from: 2020-11-29 00:00:00
# retrieving news from: 2020-11-28 00:00:00
# retrieving news from: 2020-11-27 00:00:00
# retrieving news from: 2020-11-26 00:00:00
# retrieving news from: 2020-11-25 00:00:00
# retrieving news from: 2020-11-24 00:00:00
# retrieving news from: 2020-11-23 00:00:00
# retrieving news from: 2020-11-22 00:00:00
# retrieving news from: 2020-11-21 00:00:00
# retrieving news from: 2020-11-20 00:00:00
# retrieving news from: 2020-11-19 00:00:00
# retrieving news from: 2020-11-18 00:00:00
# retrieving news from: 2020-11-17 00:00:00
# retrieving news from: 2020-11-16 00:00:00
# retrieving news from: 2020-11-15 00:00:00
# retrieving news from: 2020-11-14 00:00:00
# retrieving news from: 2020-11-13 00:00:00
# retrieving news from: 2020-11-12 00:00:00
# retrieving news from: 2020-11-11 00:00:00
# retrieving news from: 2020-11-10 00:00:00
# retrieving news from: 2020-11-09 00:00:00
# retrieving news from: 2020-11-08 00:00:00
# retrieving news from: 2020-11-07 00:00:00
# retrieving news from: 2020-11-06 00:00:00
# retrieving news from: 2020-11-05 00:00:00
# retrieving news from: 2020-11-04 00:00:00
# retrieving news from: 2020-11-03 00:00:00
# retrieving news from: 2020-11-02 00:00:00
# retrieving news from: 2020-11-01 00:00:00

# %%
# Get third topic
economy_headlines, _ = get_headlines('economy')
# Out:
# Fetching news about 'economy'
# ******************************
# retrieving news from: 2020-11-29 00:00:00
# retrieving news from: 2020-11-28 00:00:00
# retrieving news from: 2020-11-27 00:00:00
# retrieving news from: 2020-11-26 00:00:00
# retrieving news from: 2020-11-25 00:00:00
# retrieving news from: 2020-11-24 00:00:00
# retrieving news from: 2020-11-23 00:00:00
# retrieving news from: 2020-11-22 00:00:00
# retrieving news from: 2020-11-21 00:00:00
# retrieving news from: 2020-11-20 00:00:00
# retrieving news from: 2020-11-19 00:00:00
# retrieving news from: 2020-11-18 00:00:00
# retrieving news from: 2020-11-17 00:00:00
# retrieving news from: 2020-11-16 00:00:00
# retrieving news from: 2020-11-15 00:00:00
# retrieving news from: 2020-11-14 00:00:00
# retrieving news from: 2020-11-13 00:00:00
# retrieving news from: 2020-11-12 00:00:00
# retrieving news from: 2020-11-11 00:00:00
# retrieving news from: 2020-11-10 00:00:00
# retrieving news from: 2020-11-09 00:00:00
# ---------------------------------------------------------------------------
# NewsAPIException                          Traceback (most recent call last)
# <ipython-input-62-7b6092beb5e8> in <module>
#       1 # Get third topic
# ----> 2 economy_headlines, _ = get_headlines('economy')
#
# <ipython-input-59-6de7b2758076> in get_headlines(keyword)
#      15             language="en",
#      16             sort_by="relevancy",
# ---> 17             page=1,
#      18         )
#      19         headlines = []
#
# ~\anaconda3\envs\alpacaenv\lib\site-packages\newsapi\newsapi_client.py in get_everything(self, q, sources, domains, exclude_domains, from_param, to, language, sort_by, page, page_size)
#     259         # Check Status of Request
#     260         if r.status_code != requests.codes.ok:
# --> 261             raise NewsAPIException(r.json())
#     262
#     263         return r.json()
#
# NewsAPIException: {'status': 'error', 'code': 'rateLimited', 'message': 'You have made too many requests recently. Developer accounts are limited to 100 requests over a 24 hour period (50 requests available every 12 hours). Please upgrade to a paid plan if you need more requests.'}

# %%
# Get fourth topic
iphone_healdines, _ = get_headlines("iphone")

# %%
# Get fifth topic
gold_headlines, _ = get_headlines("gold")

# %%
# Instantiate SentimentIntensityAnalyzer
sid = SentimentIntensityAnalyzer()

# %%
# Create function that computes average compound sentiment of headlines for each day
def headline_sentiment_summarizer_avg(headlines):
    sentiment = []
    for day in headlines:
        day_score = []
        for h in day:
            if h == None:
                continue
            else:
                day_score.append(sid.polarity_scores(h)["compound"])
        sentiment.append(sum(day_score) / len(day_score))
    return sentiment

# %%
# Get averages of each topics sentiment
aapl_avg = headline_sentiment_summarizer_avg(aapl_headlines)
trade_avg = headline_sentiment_summarizer_avg(trade_headlines)
economy_avg = headline_sentiment_summarizer_avg(economy_headlines)
iphone_avg = headline_sentiment_summarizer_avg(iphone_headlines)
gold_avg = headline_sentiment_summarizer_avg(goldl_headlines)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-43-89fe4c764e33> in <module>
#       1 # Get averages of each topics sentiment
# ----> 2 aapl_avg = headline_sentiment_summarizer_avg(aapl_headlines)
#       3 trade_avg = headline_sentiment_summarizer_avg(trade_headlines)
#       4 economy_avg = headline_sentiment_summarizer_avg(economy_headlines)
#       5 iphone_avg = headline_sentiment_summarizer_avg(iphone_headlines)
#
# NameError: name 'aapl_headlines' is not defined

# %%
# Combine Sentiment Averages into DataFrame
topic_sentiments = pd.DataFrame({"aapl_avg": aapl_avg, "trade_avg": trade_avg, "economy_avg":economy_avg,"iphone_avg": iphone_avg,"gold_avg":gold_avg })
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-ed649b5ced3d> in <module>
#       1 # Combine Sentiment Averages into DataFrame
# ----> 2 topic_sentiments = pd.DataFrame({"aapl_avg": aapl_avg, "trade_avg": trade_avg, "economy_avg":economy_avg,"iphone_avg": iphone_avg,"gold_avg":gold_avg })
#
# NameError: name 'aapl_avg' is not defined

# %%
# Set the index value of the sentiment average DataFrame to be the series of dates.
topic_sentiments.index = pd.to_datatime(dates)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-fd0fec532c21> in <module>
#       1 # Set the index value of the sentiment average DataFrame to be the series of dates.
# ----> 2 topic_sentiments.index = pd.to_datatime(dates)
#
# AttributeError: module 'pandas' has no attribute 'to_datatime'

# %%
# Merge with AAPL returns
topic_sentiments = aapl_returns.join(topic_sentiments).dropna(how = "any")

#display Data
display(topic_sentiments)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-99227e353b1a> in <module>
#       1 # Merge with AAPL returns
# ----> 2 topic_sentiments = aapl_returns.join(topic_sentiments).dropna(how = "any")
#       3
#       4 #display Data
#       5 display(topic_sentiments)
#
# NameError: name 'topic_sentiments' is not defined

# %%
# Correlate the headlines' sentiment to returns
topic_sentiments.corr().style.background_gradient()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-ef12ca7408d9> in <module>
#       1 # Correlate the headlines' sentiment to returns
# ----> 2 topic_sentiments.corr().style.background_gradient()
#
# NameError: name 'topic_sentiments' is not defined
